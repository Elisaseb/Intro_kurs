# %% [markdown]
# ## My first notebook
# In this notebook, I will learn about the basic types of variables in Python. They are
#
#     1. Strings
#     2. integers
#     3. floats
#
# _Lets go!_

# %% [markdown]
# m = markdown
# y = code
# dd = delete
# a = new cell above
# b = new cell belowe

# %%
sentence = "The snacks were the best" 
sentence = sentence.lower()
sentence
# Out:
# 'the snacks were the best'

# %%
sentence = sentence.replace("T", "t")
sentence
# Out:
# 'the snacks were the best'

# %%
Sentence = sentence.upper()
Sentence
# Out:
# 'THE SNACKS WERE THE BEST'

# %% [markdown]
# ## Strings

# %%
# here i attempt to turn fruit into numbers
fruit1 = "grapes"
fruit2 = "bananas"

fruit1 + fruit2
# Out:
# 'grapesbananas'

# %%
#changes it to upper case, .lower() changes it to lower case 
fruit1.upper()
# Out:
# 'GRAPES'

# %%
fruit1.replace("e", "@")
# Out:
# 'grap@s'

# %%
dir(fruit1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
fruit = "2"
fruit = int(fruit)
fruit
# Out:
# 2

# %%
chips + fruit
# Out:
# 4

# %% [markdown]
# ## Integers

# %%
chips = 2
cookies = 3
snacks = chips + cookies 
print(chips)
print(cookies)
print(snacks)
print(chips, cookies, snacks)
# Out:
# 2
# 3
# 5
# 2 3 5

# %%
type(snacks)
# Out:
# int

# %%
snacks
# Out:
# 5

# %% [markdown]
# ## Floats

# %%
cookies = 3.2

# %%
type(cookies)
# Out:
# float

# %%
Chips = 1001

# %%
chips
# Out:
# 2

# %%
chips + cookies
# Out:
# 5
